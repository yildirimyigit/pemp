# %%
from matplotlib import pyplot as plt

ax, fig = plt.subplots(1, 3, figsize=(15, 5))

# %%
epochs = 1_000_000
epoch = 912453

# epoch_code is a string containing the epoch number prepended by 0s
epoch_code = str(epoch).zfill(len(str(epochs))-1)
print(epoch_code)
# Out:
# 912453
