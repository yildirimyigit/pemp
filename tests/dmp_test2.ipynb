# %%
import numpy as np
from movement_primitives.dmp import DMP
from movement_primitives.dmp._dmp import *
import matplotlib.pyplot as plt

x = np.arange(0,1.00,0.01)
nrTraj=20
sigmaNoise=0.02

A = np.array([.2, .2, .01, -.05])
X = np.vstack((np.sin(5*x), x**2, x, np.ones((1,len(x)))))
Y = np.zeros((nrTraj, len(x)))

for traj in range(nrTraj):
    sample = -np.dot(A + sigmaNoise * np.random.randn(1,4), X)[0]
    Y[traj] = sample
    label = 'Demonstrated' if traj==0 else ''
    plt.plot(x, sample, 'gray', label=label, alpha=0.2)

plt.legend()
plt.grid()
plt.title('Trajectories')
plt.xlabel('Time')
plt.ylabel('Value')
plt.tight_layout()

Y = np.expand_dims(Y, -1)
print(x.shape, Y.shape)
# Out:
# (100,) (20, 100, 1)

# %%
from copy import deepcopy

n_trajs, n_steps, n_dims = Y.shape
dt = 1/n_steps

d_ = DMP(n_dims=n_dims, n_weights_per_dim=6, dt=dt)

forcing_term_values = np.zeros_like(Y)
phase_values = np.zeros_like(Y)

for i in range(n_trajs):
    d = deepcopy(d_)
    d.imitate(x, Y[i])

    for j, t in enumerate(np.arange(0, 1, dt)):
        z = d.forcing_term.phase(t)  # Calculate the phase
        phase_values[i, j] = z
        forcing_term = d.forcing_term.forcing_term(z).squeeze()
        forcing_term_values[i, j] = forcing_term

print(forcing_term_values.shape, phase_values.shape)
# Out:
# (20, 100, 1) (20, 100, 1)

# %%
# plt.plot(x, forcing_term_values/100, label='Forcing Term/100', color='red', alpha=0.5)
plt.plot(x, Y[0].squeeze(), label='Demonstrated', color='#4d4d4d', alpha=0.4)

start = Y[1][0]
plt.scatter(0, start, color='green', label='DMP Condition #1')

d_ = deepcopy(d)
d_.configure(start_y=start)
n_step = 0

current_y = np.array([start]).reshape(n_dims,)
current_yd = np.array([0.]).reshape(n_dims,)

goal_y = np.array([Y[1][-1]]).reshape(n_dims,)

start_y = np.array([start]).reshape(n_dims,)
start_yd = goal_yd = np.array([0.]).reshape(n_dims,)
start_ydd = goal_ydd = np.array([0.]).reshape(n_dims,)

T = np.arange(0, 1+dt, dt)

traj1 = np.zeros(100)

while n_step<n_steps:

    modified_dmp_step_rk4(T[n_step], T[n_step+1], current_y, current_yd, goal_y, goal_yd, goal_ydd, 
                          start_y, start_yd, start_ydd, 1.0, 0.0, 25.0, 6.25, 
                          d_.forcing_term, forces=0)
    
    traj1[n_step] = current_y
    n_step += 1

# start = Y[0][0] + 0.1

# d_.configure(start_y=start)
# n_step = 0

# last_y = np.array([start]).reshape(n_dims,)
# last_yd = np.array([0.]).reshape(n_dims,)

# traj2 = np.zeros(100)

# while n_step<n_steps:
#     modified_dmp_step_rk4(T[n_step+1], T[n_step], last_y, last_yd, goal_y, goal_yd, goal_ydd, 
#                           np.array([start]).reshape(n_dims,), start_yd, start_ydd,
#                           1.0, 0.0, 25.0, 6.25, d_.forcing_term)

#     # print(last_y)
#     traj2[n_step] = last_y
#     n_step += 1

plt.scatter(0, start, color='green', label='DMP Condition #2')
p = plt.plot(np.linspace(0,1,100), traj1.squeeze(), label='DMP-Generated #1')
# plt.plot(np.linspace(0,1,100), traj2.squeeze(), color=p[0].get_color(), label='DMP-Generated #2')

plt.legend()
plt.grid()
# Out:
# 0.0 0.01 [0.09456567] [0.] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0
[0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.64 0.65 [0.00451985] [0.6647483] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.65 0.66 [0.01115263] [0.6604615] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.66 0.67 [0.01770215] [0.64808327] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.67 0.68 [0.02408784] [0.6277538] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.68 0.6900000000000001 [0.03023249] [0.59998785] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.6900000000000001 0.7000000000000001 [0.03606557] [0.56559551] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.7000000000000001 0.71 [0.04152577] [0.5255954] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.71 0.72 [0.04656266] [0.48113024] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.72 0.73 [0.05113753] [0.43339136] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.73 0.74 [0.05522356] [0.38355574] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.74 0.75 [0.05880542] [0.33273718] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.75 0.76 [0.06187845] [0.28195101] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.76 0.77 [0.06444757] [0.23209139] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.77 0.78 [0.06652594] [0.18391902] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.78 0.79 [0.06813368] [0.13805754] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.79 0.8 [0.06929644] [0.09499634] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.8 0.81 [0.07004416] [0.05509822] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.81 0.8200000000000001 [0.07040978] [0.01861019] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.8200000000000001 0.8300000000000001 [0.07042821] [-0.01432381] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.8300000000000001 0.84 [0.07013533] [-0.04364929] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.84 0.85 [0.06956717] [-0.06938744] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.85 0.86 [0.06875925] [-0.09162188] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.86 0.87 [0.06774596] [-0.11048611] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.87 0.88 [0.06656017] [-0.12615217] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.88 0.89 [0.06523289] [-0.13882038] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.89 0.9 [0.06379301] [-0.14871048] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.9 0.91 [0.06226715] [-0.1560539] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.91 0.92 [0.06067961] [-0.16108733] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.92 0.93 [0.0590523] [-0.16404735] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.93 0.9400000000000001 [0.05740479] [-0.16516614] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.9400000000000001 0.9500000000000001 [0.05575435] [-0.16466806] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.9500000000000001 0.96 [0.05411609] [-0.16276709] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.96 0.97 [0.052503] [-0.15966491] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.97 0.98 [0.05092615] [-0.15554967] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.98 0.99 [0.04939479] [-0.15059516] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False
# 0.99 1.0 [0.0479165] [-0.14496048] [0.03604701] [0.] [0.] [0.09456567] [0.] [0.] 1.0 0.0 25.0 6.25 <movement_primitives.dmp._forcing_term.ForcingTerm object at 0x7f42a75a22e0> None 0.001 False

# %%
new_fs = forcing_term_values

new_fs+=np.random.rand(*new_fs.shape)*1000
d_ = deepcopy(d)
d_.forcing_term.weights = new_fs

start = Y[0][0] - 0.1
plt.scatter(0, start, color='green', label='DMP Condition #1')

d_.configure(start_y=start)
t, traj1_ = d_.open_loop()
p = plt.plot(t, traj1_.squeeze(), label='Changed DMP #1')

start = Y[0][0] + 0.1
plt.scatter(0, start, color='green', label='DMP Condition #2')

d_.configure(start_y=start)
t, traj2_ = d_.open_loop()
# plt.plot(t, traj2_.squeeze(), color=p[0].get_color(), label='Changed DMP #2', alpha=0.5)
p = plt.plot(t, traj1.squeeze(), label='Original DMP #2', linestyle='--')
# plt.plot(t, traj2.squeeze(), color=p[0].get_color(), label='Original DMP #2')

plt.legend()
plt.grid()
# Out:
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit
# Yigit

# %%
for i in range(100):
    print(traj1[i], traj1_[i])
# Out:
# [-0.07783284] [-0.07783284]
# [-0.07829667] [-0.07829667]
# [-0.07970998] [-0.07970998]
# [-0.0820622] [-0.0820622]
# [-0.08529434] [-0.08529434]
# [-0.08931086] [-0.08931086]
# [-0.09399119] [-0.09399119]
# [-0.09920044] [-0.09920044]
# [-0.10479897] [-0.10479897]
# [-0.11065052] [-0.11065052]
# [-0.11662902] [-0.11662902]
# [-0.12262391] [-0.12262391]
# [-0.12854397] [-0.12854397]
# [-0.13431957] [-0.13431957]
# [-0.13990308] [-0.13990308]
# [-0.14526763] [-0.14526763]
# [-0.1504041] [-0.1504041]
# [-0.15531691] [-0.15531691]
# [-0.16001901] [-0.16001901]
# [-0.1645267] [-0.1645267]
# [-0.16885504] [-0.16885504]
# [-0.17301424] [-0.17301424]
# [-0.17700738] [-0.17700738]
# [-0.18082946] [-0.18082946]
# [-0.18446763] [-0.18446763]
# [-0.18790235] [-0.18790235]
# [-0.19110902] [-0.19110902]
# [-0.19405995] [-0.19405995]
# [-0.19672606] [-0.19672606]
# [-0.1990785] [-0.1990785]
# [-0.20108972] [-0.20108972]
# [-0.20273424] [-0.20273424]
# [-0.20398899] [-0.20398899]
# [-0.20483352] [-0.20483352]
# [-0.2052501] [-0.2052501]
# [-0.205224] [-0.205224]
# [-0.20474389] [-0.20474389]
# [-0.20380245] [-0.20380245]
# [-0.2023972] [-0.2023972]
# [-0.20053123] [-0.20053123]
# [-0.19821389] [-0.19821389]
# [-0.19546106] [-0.19546106]
# [-0.19229522] [-0.19229522]
# [-0.18874494] [-0.18874494]
# [-0.1848441] [-0.1848441]
# [-0.18063067] [-0.18063067]
# [-0.17614521] [-0.17614521]
# [-0.17142899] [-0.17142899]
# [-0.16652177] [-0.16652177]
# [-0.16145933] [-0.16145933]
# [-0.15627068] [-0.15627068]
# [-0.15097547] [-0.15097547]
# [-0.14558184] [-0.14558184]
# [-0.14008527] [-0.14008527]
# [-0.13446897] [-0.13446897]
# [-0.12870604] [-0.12870604]
# [-0.12276343] [-0.12276343]
# [-0.11660728] [-0.11660728]
# [-0.11020903] [-0.11020903]
# [-0.10355126] [-0.10355126]
# [-0.09663242] [-0.09663242]
# [-0.08946979] [-0.08946979]
# [-0.08210025] [-0.08210025]
# [-0.07457896] [-0.07457896]
# [-0.06697623] [-0.06697623]
# [-0.05937324] [-0.05937324]
# [-0.05185714] [-0.05185714]
# [-0.04451612] [-0.04451612]
# [-0.03743504] [-0.03743504]
# [-0.03069165] [-0.03069165]
# [-0.02435388] [-0.02435388]
# [-0.01847794] [-0.01847794]
# [-0.01310737] [-0.01310737]
# [-0.00827279] [-0.00827279]
# [-0.00399231] [-0.00399231]
# [-0.00027241] [-0.00027241]
# [0.00289095] [0.00289095]
# [0.0055109] [0.0055109]
# [0.00760822] [0.00760822]
# [0.00920989] [0.00920989]
# [0.01034764] [0.01034764]
# [0.01105667] [0.01105667]
# [0.01137442] [0.01137442]
# [0.01133956] [0.01133956]
# [0.01099102] [0.01099102]
# [0.01036731] [0.01036731]
# [0.00950584] [0.00950584]
# [0.00844246] [0.00844246]
# [0.00721108] [0.00721108]
# [0.00584339] [0.00584339]
# [0.0043687] [0.0043687]
# [0.00281381] [0.00281381]
# [0.001203] [0.001203]
# [-0.00044195] [-0.00044195]
# [-0.00210175] [-0.00210175]
# [-0.00375944] [-0.00375944]
# [-0.00540032] [-0.00540032]
# [-0.00701182] [-0.00701182]
# [-0.0085833] [-0.0085833]
# [-0.01010598] [-0.01010598]
