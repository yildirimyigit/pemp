# %%
import numpy as np
from xarm.wrapper import XArmAPI


root_path = "/home/yigit/projects/pemp/comparisons/pydmps/"

ROBOT_IP        = '192.168.1.225'
which_traj = 2  # 0: r_d_dmp, 1: d_dmp, 2: smp
TRAJ = 'r_d_dmp_full_denorm.npy' if which_traj == 0 else ('d_dmp_full_denorm.npy' if which_traj == 1 else 'smp_xarm_trajectory.npy')
TRAJ_PATH       = root_path + TRAJ  # 1x400x7 or 400x7
SERVO_RATE_HZ   = 100.0
TOTAL_TIME_S    = 8.0                # duration to play the whole trajectory (tune)
RAMP_TIME_S     = 1.0                # gentle ramp from current -> first waypoint
SLOW = 10
MID = 30
FAST = 50
FULL = 100

def load_traj(path):
    T = np.load(path)
    if which_traj == 2:
        #pass
        T = T*2*np.pi
    if T.ndim == 3 and T.shape[0] == 1:
        T = T[0]
    if T.shape[-1] != 7:
        raise ValueError(f'Expected last dim = 7, got {T.shape}')
    return T  # shape (N,7) in radians

def cubic_upsample(W, rate_hz, total_time_s):
    """Upsample a (N,7) waypoints array to fixed dt using cubic interpolation."""
    N = len(W)
    tq = np.linspace(0.0, 1.0, N)
    M = max(2, int(total_time_s * rate_hz))
    t  = np.linspace(0.0, 1.0, M)
    # per-joint cubic (fall back to linear if N<4)
    if N >= 4:
        from scipy.interpolate import CubicSpline  # optional; if missing, we do linear
        out = np.empty((M, 7), dtype=float)
        for j in range(7):
            out[:, j] = CubicSpline(tq, W[:, j], bc_type='clamped')(t)
        return out
    else:
        # linear fallback
        return np.stack([np.interp(t, tq, W[:, j]) for j in range(7)], axis=1)

def rad_clamp(q):
    """Basic clamp to [-pi, pi] for wrist roll etc. Remove if your limits differ."""
    q = np.asarray(q)
    q = (q + np.pi) % (2*np.pi) - np.pi
    return q

def move_home(arm):
    # Move to home position
    arm.set_position(x=470, y=0, z=425, roll=180, pitch=0, yaw=0, speed=MID, is_radian=False)

def move_center(arm):
    # Move to center position
    arm.set_position(x=470, y=0, z=310, roll=180, pitch=0, yaw=0, speed=MID, is_radian=False)

def wrap_up(arm):
    move_center(arm)
    move_home(arm)
    arm.disconnect()
# Out:
# SDK_VERSION: 1.17.0

# %%
arm = XArmAPI(ROBOT_IP, is_radian=True)  # use radians end-to-end
arm.motion_enable(True)
arm.set_mode(0); arm.set_state(0)

W = load_traj(TRAJ_PATH)              # (N,7) in radians
W_up = cubic_upsample(W, SERVO_RATE_HZ, TOTAL_TIME_S)

curr = np.array(arm.angles)
goal0 = np.array(W_up[0])
ramp_M = max(2, int(RAMP_TIME_S * SERVO_RATE_HZ))
ramp = np.stack([np.linspace(curr[j], goal0[j], ramp_M) for j in range(7)], axis=1)
# Out:
# ROBOT_IP: 192.168.1.225, VERSION: v2.4.0, PROTOCOL: V1, DETAIL: 7,7,XS1304,AC1303,v2.4.0, TYPE1300: [1, 1]
# change protocol identifier to 3
# ControllerError, code: 1
# ControllerError had clean
# ControllerError, code: 37
# ControllerError had clean
# ControllerError, code: 1
# [SDK][ERROR][2025-12-26 18:49:00][base.py:1216] - - client timeout over 90s, disconnect

# %%
import time


def stream_segment(seg):
    dt = 1.0 / SERVO_RATE_HZ
    t0 = time.time()
    for k in range(len(seg)):
        q = seg[k].tolist()  # 7 elems, radians
        arm.set_servo_angle(angle=q, is_radian=True, speed=0.25, wait=False)

        t_next = t0 + (k+1)*dt
        while time.time() < t_next:
            time.sleep(0.0005)

move_home(arm)
# time.sleep(4.0)
# try:
#     # 1) gentle ramp
#     stream_segment(ramp)
#     # 2) play the upsampled trajectory
stream_segment(W_up)
# finally:
#     # return to planner mode if you want to do other moves
#     # arm.set_mode(0); arm.set_state(0)
#     # wrap_up(arm)
#     asdad=1
# Out:
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.094167812319681
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.21907724075946
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.3443456930288793
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4700180152812585
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.595932031992121
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.7218615709720875
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.847538915327593
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.972658596238248
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.096801277161516
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.2194944168345576
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.3401671428234327
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.4582074973590777
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.5729397730136787
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.6836678793406463
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.7896818122953513
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.8902820784553667
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.9848317382738587
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.072741035992157
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.153552855947262
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.226923947681793
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.29285463052704
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.351314702357305
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.401710036228378
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.443020996454663
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.473020014527986
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.489598369732138
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.492735577767346
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.481990306384682
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.452276965484038
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.399062517837633
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.326497176633844
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.241120867477037
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.148945391690882
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.055040563836664
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.9607816649486645
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.8667181206140016
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.7746042559015818
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.686374432745793
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.6031295641017573
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.525694592866911
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.4547582834284927
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.390976288046092
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.335041077885492
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.28770318471474
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.249941640344662
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.2228334242299908
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.2075955019846014
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.205491254931402
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.2178017960052223
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.2457847315326647
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.2905534639314524
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.35305799295421
# [SDK][ERROR][2025-12-26 17:09:37][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.4336533360237125
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.532229989654518
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.6472714624931806
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.7765725426839136
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.9166787739557973
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.063667645499207
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.213249906907302
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.360998954211463
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.502384241898807
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.6328502500270705
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.747885750400591
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.843119502349862
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.9148397000899084
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.959723826257947
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.975368041841212
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.959996381142254
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.913566922489506
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.836892429990303
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.732286070348113
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.602727023030115
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.452085297848808
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.284581067382316
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.104708859535217
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.9170457518507282
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.72611143841365
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.5363874558860684
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.352252746440414
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.1779611716408285
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.0172655410047473
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.873558290461849
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.7491820494731893
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.6458695696008987
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.563974809527084
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.503113925801538
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4614589571285306
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.436531677837516
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4250557445931182
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4236545331869404
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.430021108750273
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4419395380479822
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4554767277703013
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.466546797723318
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.473828649383151
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.477123597206408
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.476906219038671
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4737629580757323
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4674725910684767
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4579229761300403
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.447462917055877
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4393182254139028
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4364674897366108
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.441769630929926
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.4579228874120655
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.487496388476692
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.53263717545316
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.595225889923624
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.6764861495972085
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.7772059905374564
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-2.89702267163467
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.034890142847167
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.1882540831695367
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.3538368776371796
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.5274915354499963
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.704663179525423
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.880363454551656
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.049376652481478
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.206121673854758
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.344963833196488
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.460865334199643
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.549225529332599
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.6067440113316955
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.63092672597373
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.621147342378287
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.577782566944511
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.502842612062726
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.399156687854962
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.270572764253974
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-4.121424341411445
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3.956495776034171
# [SDK][ERROR][2025-12-26 17:09:38][base.py:383] - - API -> set_servo_angle -> out_of_joint_range -> code=-8, i=1 value=-3