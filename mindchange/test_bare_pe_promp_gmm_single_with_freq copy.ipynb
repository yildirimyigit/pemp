# %%
import sys
import torch
from matplotlib import pyplot as plt
import numpy as np

folder_path = '../models/'
if folder_path not in sys.path:
    sys.path.append(folder_path)

folder_path = '../data/'
if folder_path not in sys.path:
    sys.path.append(folder_path)

from cnmp import CNMP

from positional_encoders import *
from plotters import *

# %%
batch_size = 1
device = torch.device("cpu")

root_path = '/home/yigit/projects/pemp/outputs/'
test_path = 'comparison/mind_change/freq/bare_pe_promp_gmm/1734968253/'

folder_path = root_path + test_path

y_train = torch.load(folder_path+'y.pt', map_location='cpu').to('cpu')
y_test = torch.load(folder_path+'y_test.pt', map_location='cpu').to('cpu')
x_train = torch.load(folder_path+'x.pt', map_location='cpu').to('cpu')
x_test = torch.load(folder_path+'x_test.pt', map_location='cpu').to('cpu')
g_train = torch.load(folder_path+'g.pt', map_location='cpu').to('cpu')
g_test = torch.load(folder_path+'g_test.pt', map_location='cpu').to('cpu')

num_demos, t_steps, dy = y_train.shape
num_test = y_test.shape[0]
num_trajs = num_demos + num_test
dx, dg, dpe = 1, 1, 27
n_max, m_max = 100, 100
max_freq = torch.max(g_train).item()
pe = generate_positional_encoding(t_steps, dpe)

Y = torch.cat([y_train, y_test], dim=0).numpy().squeeze(-1)
x = torch.cat([x_train, x_test], dim=0).numpy().squeeze(-1)
# Out:
# /tmp/ipykernel_24005/2237109236.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   y_train = torch.load(folder_path+'y.pt', map_location='cpu').to('cpu')
# /tmp/ipykernel_24005/2237109236.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   y_test = torch.load(folder_path+'y_test.pt', map_location='cpu').to('cpu')
# /tmp/ipykernel_24005/2237109236.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   x_train = torch.load(folder_path+'x.pt', map_location='cpu').to('cpu')
# /tmp/ipykernel_24005/2237109236.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   x_test = torch.load(folder_path+'x_test.pt', map_location='cpu').to('cpu')
# /tmp/ipykernel_24005/2237109236.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   g_train = torch.load(folder_path+'g.pt', map_location='cpu').to('cpu')
# /tmp/ipykernel_24005/2237109236.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   g_test = torch.load(folder_path+'g_test.pt', map_location='cpu').to('cpu')

# %%
models_folder = folder_path + 'saved_models/'
bare_path = models_folder + 'bare.pt'
pemp_path = models_folder + 'pe.pt'

enc_dims = [256,256]
dec_dims = [256,256]

bare = CNMP(input_dim=dx+dg, output_dim=dy, n_max=n_max, m_max=m_max, encoder_hidden_dims=enc_dims, decoder_hidden_dims=dec_dims, batch_size=batch_size, device=device)
pemp = CNMP(input_dim=dpe+dg, output_dim=dy, n_max=n_max, m_max=m_max, encoder_hidden_dims=enc_dims, decoder_hidden_dims=dec_dims, batch_size=batch_size, device=device)

bare.load_state_dict(torch.load(bare_path, map_location=device))
pemp.load_state_dict(torch.load(pemp_path, map_location=device))
# Out:
# /tmp/ipykernel_24005/278280830.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   bare.load_state_dict(torch.load(bare_path, map_location=device))
# /tmp/ipykernel_24005/278280830.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pemp.load_state_dict(torch.load(pemp_path, map_location=device))
# <All keys matched successfully>

# %%
# Plotting parameters
colors = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf', '#a65628', '#984ea3', '#999999', '#e41a1c', '#dede00']
linestyles = [(0, (3, 1, 1, 1, 1, 1)), '--', ':', '-.', '-', (0, (5, 10)), (0, (1, 1)), (0, (1, 3))]

promp_index = 0
bare_index = 1
pemp_index = 2

# %%
bare_obs = torch.zeros((batch_size, n_max, dx+dg+dy), dtype=torch.float32, device=device)
bare_tar_x = torch.zeros((batch_size, t_steps, dx+dg), dtype=torch.float32, device=device)

pemp_obs = torch.zeros((batch_size, n_max, dpe+dg+dy), dtype=torch.float32, device=device)
pemp_tar_x = torch.zeros((batch_size, t_steps, dpe+dg), dtype=torch.float32, device=device)

obs_mask = torch.zeros((batch_size, n_max), dtype=torch.bool, device=device)

bare_obs.fill_(0)
bare_tar_x.fill_(0)
pemp_obs.fill_(0)
pemp_tar_x.fill_(0)
obs_mask.fill_(False)

obs_mask[0, :1] = True

bare_tar_x[0, :, :dx] = torch.linspace(0, 1, t_steps).unsqueeze(1)
pemp_tar_x[0, :, :dpe] = pe

# %%
# training Contextual ProMPs

from gmr import GMM
from movement_primitives.promp import ProMP

num_promps = 30
n_weights_per_dim = 30

Ts = np.array([np.linspace(0, 1, t_steps) for _ in range(num_demos)])  # Shape: (num_demos, t_steps)
Ys = y_train.numpy()  # Shape: (num_demos, t_steps, dy)

promps = []
for i in range(num_promps - 2):
    promps.append(ProMP(n_dims=dy, n_weights_per_dim=i + 8))  # Vary weights
promps.append(ProMP(n_dims=dy, n_weights_per_dim=40))  # Fixed higher number
promps.append(ProMP(n_dims=dy, n_weights_per_dim=50))  # Fixed higher number

# Train each ProMP and collect weights
gmm_list = []  # To store GMM models for each ProMP
for promp in promps:
    print(f"     Training ProMP with {promp.n_weights_per_dim} weights     ")
    promp.imitate(Ts, Ys, n_iter=1000, min_delta=1e-6, verbose=1)  # Train ProMP

    # Extract weights from the ProMP
    n_weights_per_dim = promp.n_weights_per_dim
    weights = np.empty((num_demos, dy * n_weights_per_dim))
    for i in range(num_demos):
        weights[i] = promp.weights(Ts[i], Ys[i])

    # Train GMM with context (frequencies) and weights
    X = np.hstack((g_train, weights))  # Combine frequency (context) with weights
    gmm = GMM(n_components=5, random_state=42)
    gmm.from_samples(X)
    gmm_list.append(gmm)  # Store GMM for this ProMP
# Out:
#      Training ProMP with 8 weights
# Iteration 0001: delta = 0.106716
# Iteration 0002: delta = 0.0298497
# Iteration 0003: delta = 5.71171e-08
#      Training ProMP with 9 weights
# Iteration 0001: delta = 0.148273
# Iteration 0002: delta = 0.0619381
# Iteration 0003: delta = 9.16198e-08
#      Training ProMP with 10 weights
# Iteration 0001: delta = 0.157461
# Iteration 0002: delta = 0.066718
# Iteration 0003: delta = 8.53964e-08
#      Training ProMP with 11 weights
# Iteration 0001: delta = 0.153481
# Iteration 0002: delta = 0.0583166
# Iteration 0003: delta = 5.62375e-08
#      Training ProMP with 12 weights
# Iteration 0001: delta = 0.175285
# Iteration 0002: delta = 0.0920052
# Iteration 0003: delta = 1.47286e-07
#      Training ProMP with 13 weights
# Iteration 0001: delta = 0.178004
# Iteration 0002: delta = 0.0927655
# Iteration 0003: delta = 1.46357e-07
#      Training ProMP with 14 weights
# Iteration 0001: delta = 0.179295
# Iteration 0002: delta = 0.0881534
# Iteration 0003: delta = 1.36474e-07
#      Training ProMP with 15 weights
# Iteration 0001: delta = 0.179679
# Iteration 0002: delta = 0.0820853
# Iteration 0003: delta = 1.28358e-07
#      Training ProMP with 16 weights
# Iteration 0001: delta = 0.179842
# Iteration 0002: delta = 0.0766561
# Iteration 0003: delta = 1.2358e-07
#      Training ProMP with 17 weights
# Iteration 0001: delta = 0.180018
# Iteration 0002: delta = 0.0723158
# Iteration 0003: delta = 1.20987e-07
#      Training ProMP with 18 weights
# Iteration 0001: delta = 0.180283
# Iteration 0002: delta = 0.0690378
# Iteration 0003: delta = 1.19835e-07
#      Training ProMP with 19 weights
# Iteration 0001: delta = 0.180695
# Iteration 0002: delta = 0.0666566
# Iteration 0003: delta = 1.19902e-07
#      Training ProMP with 20 weights
# Iteration 0001: delta = 0.18126
# Iteration 0002: delta = 0.0650262
# Iteration 0003: delta = 1.20968e-07
#      Training ProMP with 21 weights
# Iteration 0001: delta = 0.181939
# Iteration 0002: delta = 0.0639803
# Iteration 0003: delta = 1.22674e-07
#      Training ProMP with 22 weights
# Iteration 0001: delta = 0.182732
# Iteration 0002: delta = 0.0634069
# Iteration 0003: delta = 1.24714e-07
#      Training ProMP with 23 weights
# Iteration 0001: delta = 0.183597
# Iteration 0002: delta = 0.0632002
# Iteration 0003: delta = 1.26794e-07
#      Training ProMP with 24 weights
# Iteration 0001: delta = 0.184537
# Iteration 0002: delta = 0.0633136
# Iteration 0003: delta = 1.29001e-07
#      Training ProMP with 25 weights
# Iteration 0001: delta = 0.18552
# Iteration 0002: delta = 0.0636783
# Iteration 0003: delta = 1.31195e-07
#      Training ProMP with 26 weights
# Iteration 0001: delta = 0.186538
# Iteration 0002: delta = 0.0642523
# Iteration 0003: delta = 1.33336e-07
#      Training ProMP with 27 weights
# Iteration 0001: delta = 0.187579
# Iteration 0002: delta = 0.0650414
# Iteration 0003: delta = 1.36709e-07
#      Training ProMP with 28 weights
# Iteration 0001: delta = 0.188619
# Iteration 0002: delta = 0.0659377
# Iteration 0003: delta = 1.38921e-07
#      Training ProMP with 29 weights
# Iteration 0001: delta = 0.189677
# Iteration 0002: delta = 0.0670158
# Iteration 0003: delta = 1.42955e-07
#      Training ProMP with 30 weights
# Iteration 0001: delta = 0.19073
# Iteration 0002: delta = 0.0681879
# Iteration 0003: delta = 1.46075e-07
#      Training ProMP with 31 weights
# Iteration 0001: delta = 0.191774
# Iteration 0002: delta = 0.0694419
# Iteration 0003: delta = 1.48561e-07
#      Training ProMP with 32 weights
# Iteration 0001: delta = 0.192813
# Iteration 0002: delta = 0.0708055
# Iteration 0003: delta = 1.5168e-07
#      Training ProMP with 33 weights
# Iteration 0001: delta = 0.193831
# Iteration 0002: delta = 0.0722363
# Iteration 0003: delta = 1.54319e-07
#      Training ProMP with 34 weights
# Iteration 0001: delta = 0.194836
# Iteration 0002: delta = 0.0737399
# Iteration 0003: delta = 1.57116e-07
#      Training ProMP with 35 weights
# Iteration 0001: delta = 0.19582
# Iteration 0002: delta = 0.0752883
# Iteration 0003: delta = 1.59644e-07
#      Training ProMP with 40 weights
# Iteration 0001: delta = 0.200423
# Iteration 0002: delta = 0.0838259
# Iteration 0003: delta = 1.79104e-07
#      Training ProMP with 50 weights
# Iteration 0001: delta = 0.207882
# Iteration 0002: delta = 0.102916
# Iteration 0003: delta = 2.05948e-07

# %%
test_traj_ind = 0
test_x_ind = 0
test_y = y_test[test_traj_ind, test_x_ind].item()
test_g = g_test[test_traj_ind].item()

# %%
# ProMP trajectories
promp_trajs = []
for idx, (promp, gmm) in enumerate(zip(promps, gmm_list)):
    freq_query = np.array([[test_g]])  # Example frequency query
    conditional_weight_distribution = gmm.condition(np.arange(1), freq_query).to_mvn()

    # Update the trained ProMP's weight distribution
    promp.from_weight_distribution(
        conditional_weight_distribution.mean,
        conditional_weight_distribution.covariance
    )

    # Add conditions and generate trajectories
    cond_point = np.array([test_y])  # Example condition point
    t = x_test[0, test_x_ind].item()
    promp.condition_position(cond_point, t=t)

    # Generate trajectory directly from the trained ProMP
    promp_trajectory = promp.sample_trajectories(x[0], 1, np.random.RandomState(seed=1234))[0]
    promp_trajs.append(promp_trajectory)

# %%
promp_dists = np.zeros(num_promps)
for idx, promp_traj in enumerate(promp_trajs):
    dist = np.linalg.norm(promp_traj - y_test[test_traj_ind].numpy())
    promp_dists[idx] = dist
    # print(f'ProMP {idx} distance: {dist}')

# %%
plt.scatter(t, cond_point, color='black', s=160, label='Condition point')
plt.plot(y_test[test_traj_ind].cpu().numpy(), color='black', label='Ground truth')
min_dist_ind = np.argmin(promp_dists)
for i in range(num_promps):
    plt.plot(promp_trajs[i], color=colors[promp_index], linestyle=linestyles[promp_index], alpha=(np.min(promp_dists)/promp_dists[i])**4, label='ProMP prediction' if i==min_dist_ind else '')

plt.grid()
plt.legend()

# %%
bare_obs[0, 0, :dx] = x_test[test_traj_ind, test_x_ind]
bare_obs[0, 0, dx:dx+dg] = test_g #g_test[test_x_ind]
bare_obs[0, 0, dx+dg:] = test_y
bare_tar_x[0, :, dx:] = test_g

pemp_obs[0, 0, :dpe] = pe[test_x_ind]
pemp_obs[0, 0, dpe:dpe+dg] = test_g #g_test[test_x_ind]
pemp_obs[0, 0, dpe+dg:] = test_y
pemp_tar_x[0, :, dpe:] = test_g

bare_trajectory = bare.val(bare_obs, bare_tar_x, obs_mask)[:, :, :dy]
pemp_trajectory = pemp.val(pemp_obs, pemp_tar_x, obs_mask)[:, :, :dy]

# %%
plt.plot(y_test[test_traj_ind].cpu().numpy(), color='black', label='Ground truth')
plt.scatter(bare_obs[0,0,0], bare_obs[0,0,2], color='black', s=160, label='Condition point')
plt.plot(bare_trajectory[0].cpu().detach().numpy(), color=colors[bare_index], linestyle=linestyles[bare_index], linewidth=2.5, label='CNMP')
plt.plot(pemp_trajectory[0].cpu().detach().numpy(), color=colors[pemp_index], linestyle=linestyles[pemp_index], linewidth=2.5, label='PEMP')
plt.grid()
plt.legend()
plt.show()
